# %%
import pandas as pd

# Load the raw data
df = pd.read_csv('../data/raw/nhl_game_data.csv')

# Display the first few rows of the dataframe
df.head(100)
# Out:
#           Date          Visitor Team              Home Team  Visitor Goals  \
# 0   2022-10-07       San Jose Sharks    Nashville Predators            1.0
# 1   2022-10-08   Nashville Predators        San Jose Sharks            3.0
# 2   2022-10-11  Vegas Golden Knights      Los Angeles Kings            4.0
# 3   2022-10-11   Tampa Bay Lightning       New York Rangers            1.0
# 4   2022-10-12        Seattle Kraken          Anaheim Ducks            4.0
# ..         ...                   ...                    ...            ...
# 95  2022-10-24   Toronto Maple Leafs   Vegas Golden Knights            1.0
# 96  2022-10-24       St. Louis Blues          Winnipeg Jets            0.0
# 97  2022-10-25          Dallas Stars          Boston Bruins            1.0
# 98  2022-10-25       Arizona Coyotes  Columbus Blue Jackets            6.0
# 99  2022-10-25   Pittsburgh Penguins         Calgary Flames            1.0
#
#     Home Goals
# 0          4.0
# 1          2.0
# 2          3.0
# ...
